# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
# Dataset Reading
df_salary = pd.read_csv('Dataset/Salary_Data.csv')

# %%
df_salary.sample(10)
# Out:
#     YearsExperience    Salary
# 17              5.3   83088.0
# 18              5.9   81363.0
# 21              7.1   98273.0
# 8               3.2   64445.0
# 3               2.0   43525.0
# 2               1.5   37731.0
# 0               1.1   39343.0
# 25              9.0  105582.0
# 6               3.0   60150.0
# 5               2.9   56642.0

# %%
# Dataset Description
df_salary.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
# Dataset Distribution
plt.title('Salary Distribution')
sns.histplot(df_salary.Salary,kde=True, stat="density", linewidth=1)
plt.show()

# %%
#Relationships between the salary and years of experience variables

plt.scatter(df_salary.YearsExperience, df_salary.Salary, color = 'Red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
#Splitting variables for X and Y learning
X = df_salary.iloc[:, :-1]
y = df_salary.iloc[:, 1:]

# %%
# Splitting dataset into test/train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Create the model and pass the data
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Create a sample DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)
print(df)
print('-----')
# Select the element in the first row and second column
element = df.iloc[0,]  # Output: 4
print(element)
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
# -----
# A    1
# B    4
# C    7
# Name: 0, dtype: int64

# %%
#Prediction
y_pred_test = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluate performance on training set
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)

print("Training set evaluation:")
print(f"Mean Absolute Error: {mae_train}")
print(f"Mean Squared Error: {mse_train}")
print(f"R-squared Score: {r2_train}")
# Out:
# Training set evaluation:
# Mean Absolute Error: 5221.078554315732
# Mean Squared Error: 36149670.11816131
# R-squared Score: 0.9411949620562126

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.show()

# %%
# Check the dimensions of X_train and y_train
print(f'X_train shape: {y_pred_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_train shape: {y_pred_train.shape}')
# Out:
# X_train shape: (6, 1)
# y_train shape: (24, 1)
# y_train shape: (24, 1)

# %%
years_of_experience = pd.DataFrame({'YearsExperience': [2]})
predicted_salary = regressor.predict(years_of_experience)
predicted_salary
# Out:
# array([[45405.24940409]])
